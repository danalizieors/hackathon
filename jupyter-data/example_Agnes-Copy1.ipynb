# %%
# %cd /home/jovyan/work/server
# Out:
# /home/jovyan/work/server

# %%
from server.persistence.database import DATABASE

# %%
DATABASE.load("../database")
print(DATABASE)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-899c61fe40fc> in <module>
# ----> 1 DATABASE.load("../database")
#       2 print(DATABASE)
#
# ~/work/server/server/persistence/PanDatabase.py in load(self, path)
#      16         for key, value in self.__dict__.items():
#      17             filename = '{}/{}.json'.format(path, key)
# ---> 18             data_frame = read_json(filename)
#      19             self.add(key, data_frame)
#      20
#
# ~/work/server/server/persistence/PanDatabase.py in read_json(filename)
#      43
#      44 def read_json(filename):
# ---> 45     return pd.read_json(filename, orient='records')
#
# /opt/conda/lib/python3.7/site-packages/pandas/io/json/_json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines, chunksize, compression)
# ...

# %%
from random import randrange

locations = ["bucharest", "budapest", "moscow", "london", "miercurea ciuc", "kairo", "tokyo"]
pollution = [90, 70, 80, 85, 30, 92, 50]
chronicConditions = ["none", "asthma", "rheumatism", "eczema"]

# skinny teenagers
for x in range(1, 50):
    indexLoc = randrange(0, 7)
    chronicConditionRdm = randrange(10)

    if chronicConditionRdm < 4:
        newline = {
			"user_token" : "aa" + str(x),
            "sex" : randrange(1, 3) * 1000,
            "year_of_birth" : randrange(1990, 2005),
            "height" : randrange(120, 190),
            "weight" : randrange(40, 70),
            "fitness" : randrange(20, 100),
            "pulse" : randrange(50, 85),
            "sleep" : randrange(35, 100),
            "noise" : pollution[indexLoc],
            "home_location" : locations[indexLoc],
            "in_temperature" : randrange(160, 330),
            "in_humidity" : randrange(30, 70),
            "chronic_condition" : randrange(1, 4)
        }
    else:
        newline = {
			"user_token" : "aa" + str(x),
            "sex" : randrange(1, 3) * 1000,
            "year_of_birth": randrange(1990, 2005),
            "height": randrange(120, 190),
            "weight": randrange(40, 70),
            "fitness": randrange(20, 100),
            "pulse": randrange(50, 85),
            "sleep": randrange(35, 100),
            "noise": pollution[indexLoc],
            "home_location": locations[indexLoc],
            "in_temperature": randrange(160, 330),
            "in_humidity": randrange(30, 70),
			"chronic_condition" : 0
        }
        
    DATABASE.add('users', newline)

# fat teenagers
for x in range(1, 50):
    indexLoc = randrange(0, 7)
    chronicConditionRdm = randrange(10)

    if chronicConditionRdm < 4:
        newline = {
			"user_token" : "aa" + str(x),
            "sex" : randrange(1, 3) * 1000,
            "year_of_birth": randrange(1990, 2005),
            "height": randrange(120, 190),
            "weight": randrange(71, 110),
            "fitness": randrange(10, 60),
            "pulse": randrange(65, 85),
            "sleep": randrange(35, 100),
            "noise": pollution[indexLoc],
            "home_location": locations[indexLoc],
            "in_temperature": randrange(160, 330),
            "in_humidity": randrange(30, 70),
            "chronic_condition" : randrange(1, 4)
        }
    else:
        newline = {
			"user_token" : "aa" + str(x),
            "sex" : randrange(1, 3) * 1000,
            "year_of_birth": randrange(1990, 2005),
            "height": randrange(120, 190),
            "weight": randrange(71, 110),
            "fitness": randrange(10, 60),
            "pulse": randrange(65, 85),
            "sleep": randrange(35, 100),
            "noise": pollution[indexLoc],
            "home_location": locations[indexLoc],
            "in_temperature": randrange(160, 330),
            "in_humidity": randrange(30, 70),
			"chronic_condition" : 0
        }
        
    DATABASE.add('users', newline)


# skinny middleage
for x in range(1, 200):
    indexLoc = randrange(0, 7)
    chronicConditionRdm = randrange(10)

    if chronicConditionRdm < 5:
        newline = {
			"user_token" : "aa" + str(x),
            "sex" : randrange(1, 3) * 1000,
            "year_of_birth": randrange(1965, 1995),
            "height": randrange(150, 200),
            "weight": randrange(50, 100),
            "fitness": randrange(30, 100),
            "pulse": randrange(49, 85),
            "sleep": randrange(35, 100),
            "noise": pollution[indexLoc],
            "home_location": locations[indexLoc],
            "in_temperature": randrange(160, 330),
            "in_humidity": randrange(30, 70),
            "chronic_condition" : randrange(1, 4)
        }
    else:
        newline = {
			"user_token" : "aa" + str(x),
            "sex" : randrange(1, 3) * 1000,
            "year_of_birth": randrange(1965, 1995),
            "height": randrange(150, 200),
            "weight": randrange(50, 100),
            "fitness": randrange(30, 100),
            "pulse": randrange(49, 85),
            "sleep": randrange(35, 100),
            "noise": pollution[indexLoc],
            "home_location": locations[indexLoc],
            "in_temperature": randrange(160, 330),
            "in_humidity": randrange(30, 70),
			"chronic_condition" : 0
        }
        
    DATABASE.add('users', newline)

# fat middleage
for x in range(1, 200):
    indexLoc = randrange(0, 7)
    chronicConditionRdm = randrange(10)

    if chronicConditionRdm < 5:
        newline = {
			"user_token" : "aa" + str(x),
            "sex" : randrange(1, 3) * 1000,
            "year_of_birth": randrange(1965, 1995),
            "height": randrange(150, 200),
            "weight": randrange(90, 140),
            "fitness": randrange(5, 75),
            "pulse": randrange(60, 85),
            "sleep": randrange(35, 100),
            "noise": pollution[indexLoc],
            "home_location": locations[indexLoc],
            "in_temperature": randrange(160, 330),
            "in_humidity": randrange(30, 70),
            "chronic_condition" : randrange(1, 4)
        }
    else:
        newline = {
			"user_token" : "aa" + str(x),
            "sex" : randrange(1, 3) * 1000,
            "year_of_birth": randrange(1965, 1995),
            "height": randrange(150, 200),
            "weight": randrange(90, 140),
            "fitness": randrange(5, 75),
            "pulse": randrange(60, 85),
            "sleep": randrange(35, 100),
            "noise": pollution[indexLoc],
            "home_location": locations[indexLoc],
            "in_temperature": randrange(160, 330),
            "in_humidity": randrange(30, 70),
			"chronic_condition" : 0
        }
        
    DATABASE.add('users', newline)

# old people
for x in range(1, 200):
    indexLoc = randrange(0, 7)
    chronicConditionRdm = randrange(10)

    if chronicConditionRdm < 8:
        newline = {
			"user_token" : "aa" + str(x),
            "sex" : randrange(1, 3) * 1000,
            "year_of_birth": randrange(1930, 1970),
            "height": randrange(150, 200),
            "weight": randrange(50, 120),
            "fitness": randrange(5, 75),
            "pulse": randrange(60, 85),
            "sleep": randrange(35, 100),
            "noise": pollution[indexLoc],
            "home_location": locations[indexLoc],
            "in_temperature": randrange(160, 330),
            "in_humidity": randrange(30, 70),
            "chronic_condition": randrange(1, 4)
        }
    else:
        newline = {
			"user_token" : "aa" + str(x),
            "sex" : randrange(1, 3) * 1000,
            "year_of_birth": randrange(1930, 1970),
            "height": randrange(150, 200),
            "weight": randrange(50, 120),
            "fitness": randrange(5, 75),
            "pulse": randrange(60, 85),
            "sleep": randrange(35, 100),
            "noise": pollution[indexLoc],
            "home_location": locations[indexLoc],
            "in_temperature": randrange(160, 330),
            "in_humidity": randrange(30, 70),
			"chronic_condition" : 0
        }
        
    DATABASE.add('users', newline)

#symptoms
#headache
#fosas


symptoms = ["headache", "diarrhea", "flu", "inflamed skin"]

#posts
for userId in range(1, 700):
    for x in range(3):
        indexSym = randrange(0, 4)
        indexLoc = randrange(0, 7)

        _symptom = symptoms[indexSym]
        _severity = randrange(1, 6)
        _temperature = randrange(-200, 330)
        _pressure = randrange(950, 1020)
        _humidity = randrange(30, 70)
        _in_temperature = randrange(160, 330)
        _in_humidity = randrange(30, 70)
        _in_dust = randrange(0, 100)
        _in_noise = pollution[indexLoc]
        _fitness = randrange(10, 100)
        _pulse = randrange(50, 75)
        _sleep = randrange(20, 100)

        newline = {
            "user_id" : userId,
            "symptom" : _symptom,
            "severity" : _severity,
            "time" : 0,
            "location" : 0,
            "temperature" : _temperature,
            "pressure" : _pressure,
            "humidity" : _humidity,
            "wind" : 0,
            "in_temperature" : _in_temperature,
            "in_humidity" : _in_humidity,
            "in_dust" : _in_dust,
            "in_noise" : _in_noise,
            "fitness" : _fitness,
            "pulse" : _pulse,
            "sleep" : _sleep
        }
        
        DATABASE.add('posts', newline)

        newline = {
            "user_id" : userId,
            "symptom" : _symptom,
            "severity" : _severity,
            "time" : 0,
            "location" : 0,
            "temperature" : _temperature + randrange(-10, 10),
            "pressure" : _pressure + randrange(-30, 0),
            "humidity" : _humidity + randrange(-30, 0),
            "wind" : 0,
            "in_temperature" : _in_temperature + randrange(-10, 10),
            "in_humidity" : _in_humidity + randrange(-10, 10),
            "in_dust" : _in_dust + randrange(-10, 10),
            "in_noise" : _in_noise + randrange(-10, 10),
            "fitness" : _fitness + randrange(-10, 10),
            "pulse" : _pulse + randrange(-10, 10),
            "sleep" : _sleep + randrange(-10, 10)
        }

        DATABASE.add('posts', newline)

tips = [
    ["Drinking more water", "Taking a nap", "Taking a chillpill"],
    ["Eating banana", "Drinking green tea", "Eating cocoiza dzsem"],
    ["Drinking tea with honey and lemon", "Eating grapefruit", "Taking a nap"],
    ["Applying body milk on your skin", "Keeping your skin dry", "Wearing clothes made from cotton instead of synthetic materials"]
    ]

#suggestions
for symptomId in range(4):
    for tipId in range(3):
        newline = {
            "symptom" : symptoms[symptomId],
            "text" : (tips[symptomId])[tipId],
            "score" : randrange(0, 100)
        }
        
        DATABASE.add('suggestions', newline)


metrics = ["pulse", "humidity"]

#targeted suggestions
for symptomId in range(4):
    for metricId in range(2):
        for relationId in range(2):
            newline = {
                "symptom" : symptoms[symptomId],
                "metric" : metrics[metricId],
                "relation" : relationId,
                "score" : randrange(0, 100)
            }
            
            DATABASE.add('targeted_suggestions', newline)
            
#links
for x in range(0, 2097):
    newline = {
        "post_id_symptom" : 2 * x + 1,
        "post_id_solution" : 2 * x + 2,
        "score" : randrange(0, 100)
    }
    
    DATABASE.add('links', newline)

# %%
DATABASE.save("../database")

# %%
#posts
for userId in range(1, 700):
    for x in range(3):
        indexSym = randrange(0, 4)
        indexLoc = randrange(0, 7)

        newline = {
            "user_id" : userId,
            "symptom" : symptoms[indexSym],
            "severity" : randrange(1, 6),
            "time" : 0,
            "location" : 0,
            "temperature" : randrange(-200, 330),
            "pressure" : randrange(950, 1020),
            "humidity" : randrange(30, 70),
            "wind" : 0,
            "in_temperature" : randrange(160, 330),
            "in_humidity" : randrange(30, 70),
            "in_dust" : randrange(0, 100),
            "in_noise" : pollution[indexLoc],
            "fitness" : randrange(10, 100),
            "pulse" : randrange(50, 75),
            "sleep" : randrange(20, 100)
        }
        
        DATABASE.add('posts', newline)
            
#links
for postId in range(2097):
    newline = {
        "post_id_symptom" = 
    }
